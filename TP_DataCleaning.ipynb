# %%
import pandas as pd

# %%
uniData = pd.read_csv("hd2016.csv")
uniData1 = uniData.filter (["UNITID","INSTNM","ADDR","CITY","ZIP","STABBR","ZIP","WEBADDR","LONGITUD","LATITUDE"],axis=1)
uniData1
uniData1.to_csv('UniData.csv')

# %%
graduationData = pd.read_csv("flags2016.csv")
graduationData
# Out:
#       UNITID  STAT_IC  LOCK_IC  IMP_IC  STAT_C  LOCK_C  PRCH_C  IDX_C PCC_F  \
# 0     100654        1        8      -2       1       8      -2     -2     .
# 1     100663        1        8      -2       1       8      -2     -2     .
# 2     100690        1        8      -2       1       8      -2     -2     .
# 3     100706        1        8      -2       1       8      -2     -2     .
# 4     100724        1        8      -2       1       8      -2     -2     .
# 5     100733        1        8      -2      -2      -2      -2     -2     .
# 6     100751        1        8      -2       1       8      -2     -2     .
# 7     100760        1        8      -2       1       8      -2     -2     .
# 8     100812        1        8      -2       1       8      -2     -2     .
# 9     100830        1        8      -2       1       8      -2     -2     .
# 10    100858        1        8      -2       1       8      -2     -2     .
# ...
